# %% [markdown]
# <a href="https://colab.research.google.com/github/mariaandraddz/Ciclo-15_pretalab_analise_de_dados/blob/main/aula2_PACOTES_E_M%C3%93DULOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math as m
from math import sqrt, log
print(sqrt(25))
# Out:
# 5.0

# %%
import random
#print("Número aleatório:", random.randint(2, 30))
lista= []
lista.append(random.randint(2, 30))
lista.append(random.randint(2, 30))
lista.append(random.randint(2, 30))
lista.append(random.randint(2, 30))
print(lista)
# Out:
# [14, 19, 19, 4]

# %%
import os

print("Diretório atual:", os.getcwd())
# Out:
# Diretório atual: /content

# %%
import datetime as dt

print("Hoje é:", dt.date.today())
# Out:
# Hoje é: 2026-03-06

# %%
import json
dados_string = '{"nome": "Duda", "cargo": "Engenheira de Dados", "experiencia": "3 anos"}'
dados_dict = json.loads(dados_string)

print(f"nome:{dados_dict['nome']}")
# Out:
# nome:Duda

# %%
dados = {
    "tema": "escuro",
    "notificações": True
}
dados["tema"] = "claro"
dados["tema"]
# Out:
# 'claro'

# %% [markdown]
# Exercício 1
#
# 1. Utilizando random gere 5 números aleatórios entre 1 e 100 e salve em uma lista
# 2. Descubra qual foi o maior e o menor número gerado

# %%
import random
lista= []
lista.append(random.randint(1, 100))
lista.append(random.randint(1, 100))
lista.append(random.randint(1, 100))
lista.append(random.randint(1, 100))
lista.append(random.randint(1, 100))
print(lista)
# Out:
# [94, 61, 41, 36, 28]

# %%
print(max(lista), min(lista))
# Out:
# 94 28

# %% [markdown]
# # CRIAÇÃO DO MÓDULO

# %%
# %%writefile utilidades.py
import math as m
def area_quadrado(l):
  return l*l

def area_retantagulo(l, a):
  return l*a
# Out:
# Overwriting utilidades.py

# %%
import utilidades as ut
ut.area_quadrado(2)
# Out:
# 4
